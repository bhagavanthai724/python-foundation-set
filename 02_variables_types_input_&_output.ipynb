# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagavanthai724/python-foundation-set/blob/main/02_variables_types_input_%26_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create variables of different types (int, float, string, bool) and print their types using type().
integer  = int(input("Enter the integer"))
floats = float(input("Enter the floating point : "))
string = input("Enter the string : ")
boolean = True #use can also try boolean = False too
print(integer , type(integer))
print(floats , type(floats))
print(string , type(string))
print(boolean , type(boolean))

# %%
# Take two integer inputs and print their sum along with the data type of the result.
a = int(input("Enter the initial number : "))
b = int(input("Enter the next number : "))
result = a + b
print(result , type(result))

# %%
# Convert a float input into an integer and a string, then print each converted type.
float_input = float(input("Enter the floating point : "))
integer = int(float_input)
string = str(float_input)
print(integer , type(integer))
print(string , type(string))

# %%
# Write a program that asks the user for their name and age, then prints a formatted f-string introduction.
name = input("Enter the name : ")
age = int(nput("Enter the age : "))
print(f"{name} is {age} years old")

# %%
# Take a user input price as string and convert it into a float; print the original type and converted type.
price = input("Enter the price : ")
float_converted = float(price)
print(type(price) , type(float_converted))

# %%
# Accept a sentence from the user and print how many characters and words it contains.
sentence = input("Enter the sentence: ")
word_count = len(sentence.split())
character_count = len(sentence)
print("Number of characters:", character_count)
print("Number of words:", word_count)

# %%
# Create a variable for marks in 5 subjects and calculate the average; print result with f-string formatting.
english = int(input("Enter the english mark : "))
maths = int(input("Enter the maths mark : "))
AI = int(input("Enter the AI mark : "))
python = int(input("Enter the python mark : "))
ML = int(input("Enter the ML mark : "))
average = (english + maths + AI + python + ML)/5
print(f"average mark : {average}")

# %%
# Ask the user for two numbers, swap them using tuple-unpacking, then print the swapped values.
a = int(input("Enter the initial value : "))
b = int(input("Enter the final value : "))
print(f"Before swapping : a : {a} , b : {b}")
a , b = b , a
print(f"After swapping : a : {a} , b : {b}")

# %%
# Create three variables (name, city, skill) and print them in a single formatted line.
name = input("Enter the name : ")
city = input("Enter the city : ")
skill = input("Enter the skill : ")
print(f"{name} has {skill} skill and is coming from {city}")

# %%
# Take input for length and width, convert them to integers, and compute the area of a rectangle.
length = int(input("Enter the length : "))
width = int(input("Enter the width : "))
area = length * width)
print(f"Area : {area}")

# %%
# Ask the user for a number and check if the type is string before conversion; then convert to int safely.
value = input("Enter a number: ")
print("Before conversion:", type(value))
number = int(value)
print("After conversion:", type(number))
print("You entered:", number)

# %%
# Demonstrate implicit type conversion by adding an int and float, then print the resultant type.
a = int(input("Enter the number : "))
b = float(input("Enter the number : "))
result = a + b
print(result , type(result))

# %%
# Demonstrate explicit type conversion by converting a numeric string into int and float.
a = input("Enter the number : ")
b = int(a)
print(a , type(a)) #initially as a string
print(b , type(b)) #converted into integer

# %%
# Take two string inputs and concatenate them with a space using both + operator and f-strings.
a = input("Enter the string 1 : ")
b = input("Enter the string 2 : ")
print(a + " " + b)

# %%
# Create a program that inputs a number as text, validates if it is numeric, and prints the correct type after conversion.
value = input("Enter a number: ")
if value.isdigit():
    print(type(int(value)))
else:
    print("Not a number")
